# %%
from ete3 import EvolTree
from ete3.treeview.layouts import evol_clean_layout
from ete3 import NCBITaxa
import matplotlib.pyplot as plt
import os
import shutil
ncbi = NCBITaxa()

def file_exists(filename):
    current_directory = os.getcwd()
    if os.path.exists(filename):
        print(f"The file {filename} exists in the current working directory {current_directory}.")
    else:
        print(f"The file {filename} does not exist in the current working directory {current_directory}.")

def organize_your_life(input_alignment):
    # get the full path of the input file
    full_input_file_path = os.path.abspath(input_alignment)
    full_input_newick_path = full_input_file_path + '.nwk'
    
    directory, alignment = os.path.split(full_input_file_path)
    directory, newick = os.path.split(full_input_newick_path)

    path = os.path.join(directory, f"{alignment}.evolTree")
    os.makedirs(path, exist_ok=True)
    
    '''
    #still learning
    print(f"directory: {directory}")
    print(f"new_directory: {path}")
    print(f"input_alignment: {input_alignment}")
    print(f"input_file_path: {full_input_file_path}")
    print(f"input_alignmentname: {input_alignmentname}")
    print(f"input_newick: {input_newick}")
    print(f"input_newickname: {input_newickname}")
    '''
    
    # copy input files the new directory
    shutil.copy(full_input_file_path, path)
    shutil.copy(full_input_newick_path, path)

    # move to the new directory
    os.chdir(path)
    print(f"EvolTree running in new folder: {path}")
    
    # load the tree
    tree = EvolTree(newick = full_input_newick_path, format=1)
    # associate alignment to tree
    tree.link_to_alignment(input_alignment)
    tree.workdir = path # set working directory where models will be saved
    alnPrefix = alignment # might need this in the future, like for saving files?
    return tree, alnPrefix
    
# Get species name from TaxID
def get_species_name(taxid):
    try:
        lineage = ncbi.get_lineage(taxid)
        names = ncbi.get_taxid_translator(lineage)
        species_name = names[taxid]
        return species_name
    except:
        return f"Unknown_species_{taxid}"

tree, alnPrefix = organize_your_life('/Users/jra/Dropbox/ciliates/beta/ete3/cenH3_1.fa.tblastn.fa.blast.annotation.centromeric.fa.extract.aligned')

#print(alignment)
#print(newick)
#print(os.getcwd())
print(tree)
#print(prefix)
# Out:
# EvolTree running in new folder: /Users/jra/Dropbox/ciliates/beta/ete3/cenH3_1.fa.tblastn.fa.blast.annotation.centromeric.fa.extract.aligned.evolTree
#
#                /-43138.PPENT_87_T0680088
#             /-|
#            |  |   /-5886.PPRIM_Ir42_T20394
#            |   \-|
#            |      \-5886.PPRIM_AZ9_T0660164
#            |
#          /-|         /-5885.PCAU_43c3d_T00320099
#         |  |      /-|
#         |  |     |   \-65128.PSEX_AZ84_T22733
#         |  |   /-|
#         |  |  |  |   /-224956.PQUADEC_NiA_T00430116
#       /-|   \-|   \-|
#      |  |     |      \-65130.PTRED_209_T71800001294020121
#      |  |     |
#      |  |      \-219701.PNOV_TE_T00130141
#      |  |
#    /-|   \-65126.PBIA_V14_T00250144
#   |  |
#   |  |      /-5888.PTET_32_T0770173
#   |  |   /-|
#   |  |  |   \-5888.PTET_51_T0800171
#   |   \-|
# --|     |   /-43137.POCT_138_T0510209
#   |      \-|
#   |         \-43137.POCT_K8_T71800002769450088
#   |
#   |--304693.PDEC_223_T01060010
#   |
#    \-304694.PDODEC_274_T00990128

# %%
# calculate dS values relative to a reference leaf
# hard-code Paramecium tetraurelia because it is Queen

def calculate_dS(reference):
    partial_leaf_name = reference
    output_txt = alnPrefix + '.ref.dS.txt'
    output_fig  = alnPrefix + '.ref.dS.pdf'
    # Initialize variables to store the reference leaf and its full name
    reference_leaf = None
    reference_leaf_name = None

    # Search for the leaf with a name that starts with the specified partial name
    for leaf in tree:
        if leaf.name.startswith(partial_leaf_name):
            reference_leaf = leaf
            reference_leaf_name = leaf.name

    if reference_leaf:
        # Calculate dS values for leaves relative to the reference leaf
        dS_values = {}

        for leaf in tree:
            # Extract TaxID from the leaf name
            taxid = int(leaf.name.split('.')[0])

            # Get the scientific name associated with the TaxID
            species_name = ncbi.get_taxid_translator([taxid]).get(taxid, leaf.name)

            # Calculate the dS value for the leaf relative to the reference leaf
            dS = reference_leaf.get_distance(leaf)
            dS_values[leaf.name] = {'Species': species_name, 'dS': dS}

        with open(output_txt, "w") as f:
            f.write('#gene\tspecies\tdS\n')
            for leaf_name, data in dS_values.items():
                print(f"{leaf_name}\t{data['Species']}\t{data['dS']:.4f}")
                f.write(f"{leaf_name}\t{data['Species']}\t{data['dS']:.4f}\n")
            print(f"Ds values have been written to {output_txt}")



        # Create a bar chart
        geneName = str(alnPrefix.split("_")[0])
        leaf_names = list(dS_values.keys())
        species_names = [data['Species'] for data in dS_values.values()]
        dS_values_list = [data['dS'] for data in dS_values.values()]

        fig, ax = plt.subplots(figsize=(10, 6))
        ax.barh(species_names, dS_values_list, color='black')
        ax.set_xlabel('dS Values')
        ax.set_title('dS Values relative to reference leaf: ' + partial_leaf_name + ' for gene ' + geneName)

        # Set x-axis limit to 1.1 if dS values are less than 1.1
        max_dS = max(dS_values_list)
        if max_dS < 1.1:
            ax.set_xlim(0, 1.1)

        # Add a red dotted line at x=1
        ax.axvline(x=1, color='red', linestyle='--')

        # Save the plot
        plt.savefig(output_fig)
        plt.show()

    else:
        print(f"No leaf found in the tree with a name starting with '{partial_leaf_name}'.")

calculate_dS('5888.PTET_51')
# Out:
# 43138.PPENT_87_T0680088	Paramecium pentaurelia	0.0725
# 5886.PPRIM_Ir42_T20394	Paramecium primaurelia	0.0825
# 5886.PPRIM_AZ9_T0660164	Paramecium primaurelia	0.0825
# 5885.PCAU_43c3d_T00320099	Paramecium caudatum	0.3659
# 65128.PSEX_AZ84_T22733	Paramecium sexaurelia	0.1595
# 224956.PQUADEC_NiA_T00430116	Paramecium quadecaurelia	0.1282
# 65130.PTRED_209_T71800001294020121	Paramecium tredecaurelia	0.1228
# 219701.PNOV_TE_T00130141	Paramecium novaurelia	0.0966
# 65126.PBIA_V14_T00250144	Paramecium biaurelia	0.0857
# 5888.PTET_32_T0770173	Paramecium tetraurelia	0.0000
# 5888.PTET_51_T0800171	Paramecium tetraurelia	0.0000
# 43137.POCT_138_T0510209	Paramecium octaurelia	0.0274
# 43137.POCT_K8_T71800002769450088	Paramecium octaurelia	0.0246
# 304693.PDEC_223_T01060010	Paramecium decaurelia	0.0288
# 304694.PDODEC_274_T00990128	Paramecium dodecaurelia	0.0300
# Ds values have been written to cenH3_1.fa.tblastn.fa.blast.annotation.centromeric.fa.extract.aligned.ref.dS.txt

# %%
# run the evolutionary models (longest step)
# intelligently checking whether a model exists was a massive waste of time because ete3 is a fucking fuck and won't "find" the models after it is relaunched

#def folder_exists(folderPath):
#    return os.path.exists(folderPath) and os.path.isdir(folderPath)

#model = ["M1", "M2", "M7", "M8", "M0", "fb"]
models = ['M1', 'M2', 'M7', 'M8']

#for model in models:
#    if not folder_exists(model):
#        tree.run_model(model)
#    else:
#        print(f"The model {model} exists. Skipping")
for model in models:
    tree.run_model(model)

# %%
# TABARNAK WHY THE FUCK CANT THIS STUPID FUCK ETE3 FIND THE FUCKING MODELS IN THE FUCKING WORKING DIRECTORY I FUCKING SPECIFIED

output_models = alnPrefix + '.models'
with open(output_models, "w") as output:
    for model in models:
        print(model)
        get_model = tree.get_evol_model(model)
        print(get_model)
        output.write(str(get_model)+'\n')
# Out:
# M1
#  Evolutionary Model M1:
#         log likelihood       : -2236.130195
#         number of parameters : 30
#         sites inference      : NEB
#         sites classes        :
#         proportions : p0=0.38887   p1=0.61113
#         w           : w0=0.08047   w1=1.0
#         branches             :
#         mark:     , omega: None      , node_ids: 16  , name: Inner13
#         mark:     , omega: 0.6424    , node_ids: 17  , name: Inner12
#         mark:     , omega: 0.6424    , node_ids: 3   , name: 304693.PDEC_223_T01060010
#         mark:     , omega: 0.6424    , node_ids: 4   , name: 304694.PDODEC_274_T00990128
#         mark:     , omega: 0.6424    , node_ids: 18  , name: Inner8
#         mark:     , omega: 0.6424    , node_ids: 26  , name: Inner11
#         mark:     , omega: 0.6424    , node_ids: 19  , name: Inner7
#         mark:     , omega: 0.6424    , node_ids: 13  , name: 65126.PBIA_V14_T00250144
#         mark:     , omega: 0.6424    , node_ids: 27  , name: Inner10
#         mark:     , omega: 0.6424    , node_ids: 28  , name: Inner9
#         mark:     , omega: 0.6424    , node_ids: 20  , name: Inner5
#         mark:     , omega: 0.6424    , node_ids: 22  , name: Inner6
#         mark:     , omega: 0.6424    , node_ids: 11  , name: 5888.PTET_32_T0770173
#         mark:     , omega: 0.6424    , node_ids: 12  , name: 5888.PTET_51_T0800171
#         mark:     , omega: 0.6424    , node_ids: 5   , name: 43137.POCT_138_T0510209
#         mark:     , omega: 0.6424    , node_ids: 6   , name: 43137.POCT_K8_T71800002769450088
#         mark:     , omega: 0.6424    , node_ids: 7   , name: 43138.PPENT_87_T0680088
#         mark:     , omega: 0.6424    , node_ids: 21  , name: Inner3
#         mark:     , omega: 0.6424    , node_ids: 23  , name: Inner4
#         mark:     , omega: 0.6424    , node_ids: 1   , name: 219701.PNOV_TE_T00130141
#         mark:     , omega: 0.6424    , node_ids: 10  , name: 5886.PPRIM_Ir42_T20394
#         mark:     , omega: 0.6424    , node_ids: 9   , name: 5886.PPRIM_AZ9_T0660164
#         mark:     , omega: 0.6424    , node_ids: 24  , name: Inner2
#         mark:     , omega: 0.6424    , node_ids: 25  , name: Inner1
#         mark:     , omega: 0.6424    , node_ids: 8   , name: 5885.PCAU_43c3d_T00320099
#         mark:     , omega: 0.6424    , node_ids: 14  , name: 65128.PSEX_AZ84_T22733
#         mark:     , omega: 0.6424    , node_ids: 2   , name: 224956.PQUADEC_NiA_T00430116
#         mark:     , omega: 0.6424    , node_ids: 15  , name: 65130.PTRED_209_T71800001294020121
#
# M2
#  Evolutionary Model M2:
#         log likelihood       : -2234.600188
#         number of parameters : 32
#         sites inference      : BEB, NEB
#         sites classes        :
#         proportions : p0=0.36542   p1=0.56288   p2=0.07169
#         w           : w0=0.0808    w1=1.0       w2=2.873
#         branches             :
#         mark:     , omega: None      , node_ids: 16  , name: Inner13
#         mark:     , omega: 0.7984    , node_ids: 17  , name: Inner12
#         mark:     , omega: 0.7984    , node_ids: 3   , name: 304693.PDEC_223_T01060010
#         mark:     , omega: 0.7984    , node_ids: 4   , name: 304694.PDODEC_274_T00990128
#         mark:     , omega: 0.7984    , node_ids: 18  , name: Inner8
#         mark:     , omega: 0.7984    , node_ids: 26  , name: Inner11
#         mark:     , omega: 0.7984    , node_ids: 19  , name: Inner7
#         mark:     , omega: 0.7984    , node_ids: 13  , name: 65126.PBIA_V14_T00250144
#         mark:     , omega: 0.7984    , node_ids: 27  , name: Inner10
#         mark:     , omega: 0.7984    , node_ids: 28  , name: Inner9
#         mark:     , omega: 0.7984    , node_ids: 20  , name: Inner5
#         mark:     , omega: 0.7984    , node_ids: 22  , name: Inner6
#         mark:     , omega: 0.7984    , node_ids: 11  , name: 5888.PTET_32_T0770173
#         mark:     , omega: 0.7984    , node_ids: 12  , name: 5888.PTET_51_T0800171
#         mark:     , omega: 0.7984    , node_ids: 5   , name: 43137.POCT_138_T0510209
#         mark:     , omega: 0.7984    , node_ids: 6   , name: 43137.POCT_K8_T71800002769450088
#         mark:     , omega: 0.7984    , node_ids: 7   , name: 43138.PPENT_87_T0680088
#         mark:     , omega: 0.7984    , node_ids: 21  , name: Inner3
#         mark:     , omega: 0.7984    , node_ids: 23  , name: Inner4
#         mark:     , omega: 0.7984    , node_ids: 1   , name: 219701.PNOV_TE_T00130141
#         mark:     , omega: 0.7984    , node_ids: 10  , name: 5886.PPRIM_Ir42_T20394
#         mark:     , omega: 0.7984    , node_ids: 9   , name: 5886.PPRIM_AZ9_T0660164
#         mark:     , omega: 0.7984    , node_ids: 24  , name: Inner2
#         mark:     , omega: 0.7984    , node_ids: 25  , name: Inner1
#         mark:     , omega: 0.7984    , node_ids: 8   , name: 5885.PCAU_43c3d_T00320099
#         mark:     , omega: 0.7984    , node_ids: 14  , name: 65128.PSEX_AZ84_T22733
#         mark:     , omega: 0.7984    , node_ids: 2   , name: 224956.PQUADEC_NiA_T00430116
#         mark:     , omega: 0.7984    , node_ids: 15  , name: 65130.PTRED_209_T71800001294020121
#
# M7
#  Evolutionary Model M7:
#         log likelihood       : -2236.663782
#         number of parameters : 30
#         sites inference      : NEB
#         sites classes        :
#         proportions : p0=0.125     p1=0.125     p2=0.125     p3=0.125     p4=0.125     p5=0.125     p6=0.125     p7=0.125
#         w           : w0=0.00015   w1=0.02831   w2=0.26502   w3=0.71445   w4=0.95054   w5=0.99623   w6=0.99993   w7=1.0
#         branches             :
#         mark:     , omega: None      , node_ids: 16  , name: Inner13
#         mark:     , omega: 0.6193    , node_ids: 17  , name: Inner12
#         mark:     , omega: 0.6193    , node_ids: 3   , name: 304693.PDEC_223_T01060010
#         mark:     , omega: 0.6193    , node_ids: 4   , name: 304694.PDODEC_274_T00990128
#         mark:     , omega: 0.6193    , node_ids: 18  , name: Inner8
#         mark:     , omega: 0.6193    , node_ids: 26  , name: Inner11
#         mark:     , omega: 0.6193    , node_ids: 19  , name: Inner7
#         mark:     , omega: 0.6193    , node_ids: 13  , name: 65126.PBIA_V14_T00250144
#         mark:     , omega: 0.6193    , node_ids: 27  , name: Inner10
#         mark:     , omega: 0.6193    , node_ids: 28  , name: Inner9
#         mark:     , omega: 0.6193    , node_ids: 20  , name: Inner5
#         mark:     , omega: 0.6193    , node_ids: 22  , name: Inner6
#         mark:     , omega: 0.6193    , node_ids: 11  , name: 5888.PTET_32_T0770173
#         mark:     , omega: 0.6193    , node_ids: 12  , name: 5888.PTET_51_T0800171
#         mark:     , omega: 0.6193    , node_ids: 5   , name: 43137.POCT_138_T0510209
#         mark:     , omega: 0.6193    , node_ids: 6   , name: 43137.POCT_K8_T71800002769450088
#         mark:     , omega: 0.6193    , node_ids: 7   , name: 43138.PPENT_87_T0680088
#         mark:     , omega: 0.6193    , node_ids: 21  , name: Inner3
#         mark:     , omega: 0.6193    , node_ids: 23  , name: Inner4
#         mark:     , omega: 0.6193    , node_ids: 1   , name: 219701.PNOV_TE_T00130141
#         mark:     , omega: 0.6193    , node_ids: 10  , name: 5886.PPRIM_Ir42_T20394
#         mark:     , omega: 0.6193    , node_ids: 9   , name: 5886.PPRIM_AZ9_T0660164
#         mark:     , omega: 0.6193    , node_ids: 24  , name: Inner2
#         mark:     , omega: 0.6193    , node_ids: 25  , name: Inner1
#         mark:     , omega: 0.6193    , node_ids: 8   , name: 5885.PCAU_43c3d_T00320099
#         mark:     , omega: 0.6193    , node_ids: 14  , name: 65128.PSEX_AZ84_T22733
#         mark:     , omega: 0.6193    , node_ids: 2   , name: 224956.PQUADEC_NiA_T00430116
#         mark:     , omega: 0.6193    , node_ids: 15  , name: 65130.PTRED_209_T71800001294020121
#
# M8
#  Evolutionary Model M8:
#         log likelihood       : -2234.513361
#         number of parameters : 32
#         sites inference      : BEB, NEB
#         sites classes        :
#         proportions : p0=0.11218   p1=0.11218   p2=0.11218   p3=0.11218   p4=0.11218   p5=0.11218   p6=0.11218   p7=0.11218   p8=0.10255
#         w           : w0=0.00072   w1=0.03922   w2=0.22341   w3=0.55583   w4=0.84107   w5=0.96809   w6=0.9975    w7=0.99999   w8=2.49866
#         branches             :
#         mark:     , omega: None      , node_ids: 16  , name: Inner13
#         mark:     , omega: 0.7752    , node_ids: 17  , name: Inner12
#         mark:     , omega: 0.7752    , node_ids: 3   , name: 304693.PDEC_223_T01060010
#         mark:     , omega: 0.7752    , node_ids: 4   , name: 304694.PDODEC_274_T00990128
#         mark:     , omega: 0.7752    , node_ids: 18  , name: Inner8
#         mark:     , omega: 0.7752    , node_ids: 26  , name: Inner11
#         mark:     , omega: 0.7752    , node_ids: 19  , name: Inner7
#         mark:     , omega: 0.7752    , node_ids: 13  , name: 65126.PBIA_V14_T00250144
#         mark:     , omega: 0.7752    , node_ids: 27  , name: Inner10
#         mark:     , omega: 0.7752    , node_ids: 28  , name: Inner9
#         mark:     , omega: 0.7752    , node_ids: 20  , name: Inner5
#         mark:     , omega: 0.7752    , node_ids: 22  , name: Inner6
#         mark:     , omega: 0.7752    , node_ids: 11  , name: 5888.PTET_32_T0770173
#         mark:     , omega: 0.7752    , node_ids: 12  , name: 5888.PTET_51_T0800171
#         mark:     , omega: 0.7752    , node_ids: 5   , name: 43137.POCT_138_T0510209
#         mark:     , omega: 0.7752    , node_ids: 6   , name: 43137.POCT_K8_T71800002769450088
#         mark:     , omega: 0.7752    , node_ids: 7   , name: 43138.PPENT_87_T0680088
#         mark:     , omega: 0.7752    , node_ids: 21  , name: Inner3
#         mark:     , omega: 0.7752    , node_ids: 23  , name: Inner4
#         mark:     , omega: 0.7752    , node_ids: 1   , name: 219701.PNOV_TE_T00130141
#         mark:     , omega: 0.7752    , node_ids: 10  , name: 5886.PPRIM_Ir42_T20394
#         mark:     , omega: 0.7752    , node_ids: 9   , name: 5886.PPRIM_AZ9_T0660164
#         mark:     , omega: 0.7752    , node_ids: 24  , name: Inner2
#         mark:     , omega: 0.7752    , node_ids: 25  , name: Inner1
#         mark:     , omega: 0.7752    , node_ids: 8   , name: 5885.PCAU_43c3d_T00320099
#         mark:     , omega: 0.7752    , node_ids: 14  , name: 65128.PSEX_AZ84_T22733
#         mark:     , omega: 0.7752    , node_ids: 2   , name: 224956.PQUADEC_NiA_T00430116
#         mark:     , omega: 0.7752    , node_ids: 15  , name: 65130.PTRED_209_T71800001294020121

# %%
def get_pvals(alt, neg):
    pval = tree.get_most_likely(alt, neg)
    output_file = alnPrefix + '.pvals'
    with open(output_file, "w") as output:
        output.write('altModel\tnegModel\tpval\n')
        output.write(alt + '\t' + neg  +  '\t' + str(pval) + '\n')
    print(f'LRT values output to: {output_file}')
    
    if pval < 0.05:
        output2 = alnPrefix + '.sigAAs'
        print(f'{alt} model wins.')
        for s in range(len(alt.sites['BEB']['aa'])):
            if alt.sites['BEB']['p2'][s] > 0.95:
                print('positively selected site %s at position: %s, with probability: %s' % (alt.sites['BEB']['aa'][s], s+1, alt.sites['BEB']['p2'][s]))
                output2.write('positively selected site' + alt.sites['BEB']['aa'][s] + 'at position:' + s+1 + 'with probability:' + alt.sites['BEB']['p2'][s])
    else:
        print(f'{neg} model is not rejected')
        
get_pvals('M2', 'M1')
get_pvals('M8', 'M7')
# Out:
# LRT values output to: cenH3_1.fa.tblastn.fa.blast.annotation.centromeric.fa.extract.aligned.pvals
# M1 model is not rejected
# LRT values output to: cenH3_1.fa.tblastn.fa.blast.annotation.centromeric.fa.extract.aligned.pvals
# M7 model is not rejected

# %%
def evol_graphs(alt, neg, suffix):
    
    # Change the colours
    col_line = {'NS' : '#000000', 
           'RX' : '#000000', 'RX+': '#000000', 
           'CN' : '#000000', 'CN+': '#000000', 
           'PS' : '#000000', 'PS+': '#000000'}
    col_bar = {'NS' : '#BCBCBC', 
           'RX' : '#5D63AB', 'RX+': '#5D63AB', 
           'CN' : '#659A62', 'CN+': '#659A62', 
           'PS' : '#F4C95D', 'PS+': '#F4C95D'}

    # Print the first tree without naming branches
    alt_model = tree.get_evol_model(alt)
    neg_model = tree.get_evol_model(neg)

    alt_model.set_histface(up=True, colors=col_line, errors=True, kind='curve', ylim=[0,20], hlines = [1], hlines_col=['black'])
    tree.render(alnPrefix +  '.' + alt + suffix + '.line.pdf', histfaces=[alt])

    alt_model.set_histface(up=True, colors=col_bar, errors=True, kind='stick', ylim=[0,4], hlines = [1], hlines_col=['black'])
    tree.render(alnPrefix +  '.' + alt + suffix + '.bar.pdf', histfaces=[alt])

def modify_leaf_names():
    # Modify the tree leaf names
    # ONLY DO THIS AS THE LAST STEP
    for leaf in tree.iter_leaves():
        taxid = int(leaf.name.split('.')[0])
        species_name = get_species_name(taxid)
        leaf.name = species_name

    

    
evol_graphs('M2', 'M1', '')
evol_graphs('M8', 'M7', '')
modify_leaf_names()
evol_graphs('M2', 'M1', '_sp')
evol_graphs('M8', 'M7', '_sp')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-a1e17129bd6e> in <module>
#      34 evol_graphs('M2', 'M1', '')
#      35 evol_graphs('M8', 'M7', '')
# ---> 36 modify_leaf_names()
#      37 evol_graphs('M2', 'M1', '_sp')
#      38 evol_graphs('M8', 'M7', '_sp')
#
# <ipython-input-23-a1e17129bd6e> in modify_leaf_names()
#      25     # ONLY DO THIS AS THE LAST STEP
#      26     for leaf in tree.iter_leaves():
# ---> 27         taxid = int(leaf.name.split('.')[0])
#      28         species_name = get_species_name(taxid)
#      29         leaf.name = species_name
#
# ValueError: invalid literal for int() with base 10: 'Paramecium pentaurelia'
